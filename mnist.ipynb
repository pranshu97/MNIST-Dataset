# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras import optimizers,regularizers
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten
from sklearn import metrics

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(x_train.shape[0],28,28,1)
x_test = x_test.reshape(x_test.shape[0], 28,28, 1)
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
model = Sequential()

model.add(Conv2D(filters=14,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPool2D())

model.add(Conv2D(filters=14,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D())

model.add(Conv2D(filters=14,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(1,1)))

model.add(Flatten())
model.add(Dense(256,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))

adam = optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=adam,loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,batch_size=64,epochs=10,use_multiprocessing=True)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0967 - accuracy: 0.8502
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0245 - accuracy: 0.9561
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0175 - accuracy: 0.9698
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0144 - accuracy: 0.9746
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0116 - accuracy: 0.9802
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0102 - accuracy: 0.9822
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0090 - accuracy: 0.9846
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0079 - accuracy: 0.9865
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9875
# Epoch 10/10
# ...

# %%
y_pred = model.predict(x_test)
y_pred = np.where(y_pred>0.5,1,0)

# %%
acc = metrics.accuracy_score(y_test,y_pred)
acc
# Out:
# 0.9836
